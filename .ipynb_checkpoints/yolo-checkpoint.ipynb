# %%
import ultralytics
ultralytics.checks()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import ultralytics
#       2 ultralytics.checks()
#
# ModuleNotFoundError: No module named 'ultralytics'

# %%
import torch
print("Torch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("Device count:", torch.cuda.device_count())

# %%
from ultralytics import YOLO
model = YOLO('yolo11n.pt')

# %%
from pathlib import Path
root = Path('./skin_dataset').resolve() # root dataset path

results = model.train(
    data=str(data_yaml),
    epochs=30,
    imgsz=640,
    batch=16,
    device=0,
    project="runs",
    name="skin_yolo_run",
    seed=0,
    patience=20,
    verbose=True
)

# %%
from pathlib import Path
import shutil

best_weights = Path("runs/detect/skin_yolo_run/weights/best.pt")
target_weights = Path("skin_yolo.pt")

if best_weights.exists():
    shutil.copy(best_weights, target_weights)
    print("Saved best model as:", target_weights.resolve())
else:
    raise FileNotFoundError(f"Could not find {best_weights}. Did training finish successfully?")
